# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from sklearn.neighbors import KNeighborsClassifier

# %%
file_path = "./magic/magic04.data"
cols = ["fLength", "fWidth", "fSize", "fConc", "fConc1", "fAsym", "fM3Long", "fM3Trans", "fAlpha", "fDist", "class"]
raw_data = pd.read_csv(file_path, names = cols)

# %%
Y = raw_data["class"]
# Y.head()
feature = ["fLength", "fWidth", "fSize", "fConc", "fConc1", "fAsym", "fM3Long", "fM3Trans", "fAlpha", "fDist"]
X = raw_data[feature]
# X.head()

# %%
print(pd.unique(Y))
# Out:
# ['g' 'h']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, random_state = 5)

# %%
knn = KNeighborsClassifier(n_neighbors = 2)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
knn.score(x_test, y_test)
# Out:
# 0.7828601472134595

# %%
y_pred = knn.predict(x_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            g       0.77      0.95      0.85      3665
#            h       0.85      0.47      0.61      2041
#
#     accuracy                           0.78      5706
#    macro avg       0.81      0.71      0.73      5706
# weighted avg       0.80      0.78      0.76      5706
